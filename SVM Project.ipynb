# %%
#Import the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import os
from zipfile import ZipFile

# %%
#read the data
df = pd.read_csv('voice1 (1).csv')

# %%
df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %% [markdown]
# ### Build the ML model which will predict the gender by voice
# - voice recognition project

# %%
df['label'].value_counts()
# Out:
# male      1584
# female    1584
# Name: label, dtype: int64

# %%
df.corr()
# Out:
#           meanfreq        sd    median       Q25       Q75       IQR  \
# meanfreq  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# sd       -0.739039  1.000000 -0.562603 -0.846931 -0.161076  0.874660
# median    0.925445 -0.562603  1.000000  0.774922  0.731849 -0.477352
# Q25       0.911416 -0.846931  0.774922  1.000000  0.477140 -0.874189
# Q75       0.740997 -0.161076  0.731849  0.477140  1.000000  0.009636
# IQR      -0.627605  0.874660 -0.477352 -0.874189  0.009636  1.000000
# skew     -0.322327  0.314597 -0.257407 -0.319475 -0.206339  0.249497
# kurt     -0.316036  0.346241 -0.243382 -0.350182 -0.148881  0.316185
# sp.ent   -0.601203  0.716620 -0.502005 -0.648126 -0.174905  0.640813
# sfm      -0.784332  0.838086 -0.661690 -0.766875 -0.378198  0.663601
# mode      0.687715 -0.529150  0.677433  0.591277  0.486857 -0.403764
# centroid  1.000000 -0.739039  0.925445  0.911416  0.740997 -0.627605
# meanfun   0.460844 -0.466281  0.414909  0.545035  0.155091 -0.534462
# ...

# %%
df.isna().sum()
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %%
df.shape
# Out:
# (3168, 21)

# %%
df['label'].value_counts()
# Out:
# male      1584
# female    1584
# Name: label, dtype: int64

# %%
print('Total Number of label : {}'.format(df.shape[0]))
# Out:
# Total Number of label : 3168

# %%
X = df.iloc[:, :-1]
X.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm      mode  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  0.000000  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  0.000000  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  0.000000  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  0.083878  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  0.104261  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx
# ...

# %%
y = df['label']

# %% [markdown]
# ## Converting string value to int type for labels

# %%
from sklearn.preprocessing import LabelEncoder
y = df.iloc[:, -1]

gender_encoder = LabelEncoder()
y = gender_encoder.fit_transform(y)

# %%
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# ...

# %% [markdown]
# ### Data standardisation

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# %%
X
# Out:
# array([[-4.04924806,  0.4273553 , -4.22490077, ..., -1.43142165,
#         -1.41913712, -1.45477229],
#        [-3.84105325,  0.6116695 , -3.99929342, ..., -1.41810716,
#         -1.4058184 , -1.01410294],
#        [-3.46306647,  1.60384791, -4.09585052, ..., -1.42920257,
#         -1.41691733, -1.06534356],
#        ...,
#        [-1.29877326,  2.32272355, -0.05197279, ..., -0.5992661 ,
#         -0.58671739,  0.17588664],
#        [-1.2452018 ,  2.012196  , -0.01772849, ..., -0.41286326,
#         -0.40025537,  1.14916112],
#        [-0.51474626,  2.14765111, -0.07087873, ..., -1.27608595,
#         -1.2637521 ,  1.47567886]])

# %% [markdown]
# ### Splitting the data into train and test

# %%
from sklearn.model_selection import train_test_split, cross_val_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = 2)

# %% [markdown]
# ### Run the SVM

# %%
from sklearn.svm import SVC

# %%
from sklearn.metrics import accuracy_score

# %%
svc = SVC()

# %%
svc.fit(X_train, y_train)
# Out:
# SVC()

# %%
#step3- model prediction
y_pred = svc.predict(X_test)

# %%
print('Accuracy_score:')
print(accuracy_score(y_test, y_pred))
# Out:
# Accuracy_score:
# 0.9747634069400631

# %% [markdown]
# ## Default linear kernel

# %%
svc = SVC(kernel = 'linear')
svc.fit(X_train, y_train)
y_pred = svc.predict(X_test)
print('Accuracy_score:')
print(accuracy_score(y_test, y_pred))
# Out:
# Accuracy_score:
# 0.9716088328075709

# %% [markdown]
# ## Default rbf kernel

# %%
svc = SVC(kernel = 'rbf')
svc.fit(X_train, y_train)
y_pred = svc.predict(X_test)
print('Accuracy_score:')
print(accuracy_score(y_test, y_pred))
# Out:
# Accuracy_score:
# 0.9747634069400631

# %% [markdown]
# ### Default Polynomial Kernel

# %%
svc = SVC(kernel = 'poly')
svc.fit(X_train, y_train)
y_pred = svc.predict(X_test)
print('Accuracy_score:')
print(accuracy_score(y_test, y_pred))
# Out:
# Accuracy_score:
# 0.9526813880126183

# %% [markdown]
# ### Taking all the values of C and Checking out the accuracy score with kernel as linear

# %%
C_range = list(range(1,26))
acc_score = []
for c in C_range:
    svc = SVC(kernel = 'linear', C = c)
    scores = cross_val_score(svc, X,y, cv = 10, scoring = 'accuracy')
    acc_score.append(scores.mean())
print(acc_score)
# Out:
# [0.9696991175178692, 0.969068202691371, 0.969068202691371, 0.969068202691371, 0.9693836601046201, 0.9693836601046201, 0.969068202691371, 0.9687527452781215, 0.9684372878648724, 0.9684372878648724, 0.9684372878648724, 0.9684372878648724, 0.9681208321686698, 0.9681208321686698, 0.9681208321686698, 0.9681208321686698, 0.9678043764724673, 0.9678043764724673, 0.9678043764724673, 0.9678043764724673, 0.9681208321686698, 0.968436289581919, 0.968436289581919, 0.9681198338857164, 0.9681198338857164]

# %%
import matplotlib.pyplot as plt

C_values = list(range(1,26))
plt.plot(C_values, acc_score)
plt.xticks(np.arange(0,27,2))
plt.xlabel('Value of C for SVC')
plt.ylabel('Cross-validated Accuracy')
# Out:
# Text(0, 0.5, 'Cross-validated Accuracy')

# %% [markdown]
# ### Accuracy score is highest for C= 0.1

# %%
gamma_range = [0.0001,0.001,0.01,0.1,1,10,100]
acc_score = []
for g in gamma_range:
    svc = SVC(kernel = 'rbf', gamma = g)
    scores = cross_val_score(svc, X, y, cv = 10, scoring = 'accuracy')
    acc_score.append(scores.mean())
print(acc_score)
# Out:
# [0.888240226809887, 0.9551820868106857, 0.9681168390368565, 0.9636874575729744, 0.9061883560276325, 0.6016421754582119, 0.49905362776025236]

# %%
import matplotlib.pyplot as plt

gamm_range = gamma_range = [0.0001,0.001,0.01,0.1,1,10,100]
plt.plot(gamm_range, acc_score)
plt.xticks(np.arange(0.0001, 100,5))
plt.xlabel('Value of gamma for SVC')
plt.ylabel('Cross-validated Accuracy')
# Out:
# Text(0, 0.5, 'Cross-validated Accuracy')

# %%
df = pd.DataFrame({
    'Income' : [15000,1800,120000,1000],
    'Age' : [25,18,42,51],
    'Department' : ['HR', 'Legal', 'Marketing', 'Management']
})

# %%
df.head()
# Out:
#    Income  Age  Department
# 0   15000   25          HR
# 1    1800   18       Legal
# 2  120000   42   Marketing
# 3    1000   51  Management

# %%
df_scaled = df.copy()
col_names = ['Income', 'Age']
features = df_scaled[col_names]

# %%
features
# Out:
#    Income  Age
# 0   15000   25
# 1    1800   18
# 2  120000   42
# 3    1000   51

# %% [markdown]
# ### 1) MinMax Scaler
# - X_scaled = (x-xmin)/(Xmax-x_min)
# - scales all the data from 0 to 1

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
df_scaled[col_names] = scaler.fit_transform(features.values)

# %%
df_scaled
# Out:
#      Income       Age  Department
# 0  0.117647  0.212121          HR
# 1  0.006723  0.000000       Legal
# 2  1.000000  0.727273   Marketing
# 3  0.000000  1.000000  Management

# %% [markdown]
# ### 2) Standard Scaler
# - X_scaled = (x-mean)/std dev
# - converts columns into normal distribution

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
df_scaled[col_names] = scaler.fit_transform(features.values)
df_scaled
# Out:
#      Income       Age  Department
# 0 -0.391315 -0.685248          HR
# 1 -0.656886 -1.218219       Legal
# 2  1.721183  0.609110   Marketing
# 3 -0.672981  1.294358  Management

# %% [markdown]
# ### 3) Max abs Scaler
# - -1 to 1

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
scalar = MaxAbsScaler()

# %%
df_scaled[col_names] = scaler.fit_transform(features.values)

# %%
df_scaled
# Out:
#      Income       Age  Department
# 0 -0.391315 -0.685248          HR
# 1 -0.656886 -1.218219       Legal
# 2  1.721183  0.609110   Marketing
# 3 -0.672981  1.294358  Management

# %% [markdown]
# ### 4) Robust Scaler
# - Scaling, theroetical part discus
